# %%
abreviate=[("Los Angeles International Airport","ORD"),
           ("Dallas/Fort Worth International Airport","DFW")
           ,("Denver International Airport ","DEN"),("O’Hare International Airport","ORD")]

           


#can not iterate tuple mare than 2.

# %%
for (i,j) in abreviate:
    print("The code for {} is {}.".format(i,j))
    
#only two variables can be use in each tuple.
# Out:
# The code for Los Angeles International Airport is ORD.
# The code for Dallas/Fort Worth International Airport is DFW.
# The code for Denver International Airport  is DEN.
# The code for O’Hare International Airport is ORD.

# %%
#open file

# %%
z=open("/Users/mac/Desktop/T1.text","r")
#跟z=open("route")是一樣的
print(z.read())
# Out:
# Here is my boy
#  nono

# %%
z.read()
#不會顯示,因為上一次執行已經讀到尾巴了,check position
z.tell()
z.seek(0)
#操作回頁首
z.read()
z.close()
print(z.closed)
#attribute to know
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-e2eb02fb8f56> in <module>
# ----> 1 z.read()
#       2 #不會顯示,因為上一次執行已經讀到尾巴了,check position
#       3 z.tell()
#       4 z.seek(0)
#       5 #操作回頁首
#
# ValueError: I/O operation on closed file.

# %%
#內建函數,with route as file name,自動開,後關檔案
with open("/Users/mac/Desktop/T1.text") as T1:
    for i in T1:
        print(i.rstrip())
# Out:
# 蝦皮購物   蝦拼開箱 查看全部     回首頁 所有商品 ✨2/25特賣20點【天絲枕套/單床包$199up】🔥滿額輸碼最高折１００！ 【蚊帳專區】3秒彈開方型款／蒙古包款 【單一件】天絲系列 【防水防蟎】保潔墊／枕墊 100%防水護理級天絲床包式保潔墊/枕套 單人/雙人/加人/特大 TD
# $263 - $950
# 2177
# (2391)
# 8.8折 059專利二開門簾式蚊帳-雙開門帳篷蒙古包 防小黑蚊進入【免拉鍊垂簾式 窗簾式更進出方便】三秒快速彈開免安裝
# $700
# $616
# 622
# (646)
# 8.8折 蒙娜麗莎天絲絨枕/七孔棉枕/加高型枕頭 飯店民宿御用枕MIT台灣製造 【美國授權】雅妮詩-QQ
# $196 - $774
# 948
# (794)
# 5.2折 雅妮詩 60支精梳棉緹花枕頭套 300針純棉枕套1對2入 歐美零碼純棉枕墊 緹花枕套 DT
# $169 - $196
# 342
# (563)
# 8.5折 雅妮詩 方型雙開門簾蚊帳 3秒彈開式無拉鍊防蚊帳 專利方型空間【單 雙 加】防蚊垂簾蒙古包蚊帳 069
# $1,200
# 314
# (355) 60支100%天絲枕套枕頭套 天絲床包 單 雙 加 4009
# $196 - $638
# 1
# 尚未有評價
# 5折 查看全部 059專利二開門簾式蚊帳-雙開門帳篷蒙古包 防小黑蚊進入【免拉鍊垂簾式 窗簾式更進出方便】三秒快速彈開免安裝
# $700
# $616
# 622
# (646)
# 8.8折 雅妮詩 方型雙開門簾蚊帳 3秒彈開式無拉鍊防蚊帳 專利方型空間【單 雙 加】防蚊垂簾蒙古包蚊帳 069
# $1,200
# 314
# (355) 【現貨免運】080拉鍊專利方型蚊帳-單人5呎雙人6呎加大特大三開門彈開式防蚊帳．防蚊門簾大空間蒙古包蚊帳 防小黑蚊/蚊子
# $1,150
# $1,012
# 103
# (83)
# 8.8折 【門簾式雙專利】5呎雙人 079三開門彈開式防蚊帳 預防蚊子/小黑蚊 登革熱【免拉鍊進出方便】A-nice雅妮詩
# $1,080
# $950
# 49
# (58)
# 8.8折 【現貨】頂級三開門蒙古包蚊帳 077 雙人【160cm超大空間】雙層防蚊/防小黑蚊蒼蠅&預防登革熱
# $1,050
# ...

# %%
with open("/Users/mac/Desktop/T1.text","w") as T2:
    T2.write("Here is my boy\r nono")
with open("/Users/mac/Desktop/T1.text") as T2:
    print(T2.read())
# Out:
# <_io.TextIOWrapper name='/Users/mac/Desktop/T1.text' mode='r' encoding='UTF-8'>

# %%
print(T2)
T2.close()
T2.closed
# Out:
# <_io.TextIOWrapper name='/Users/mac/Desktop/T1.text' mode='r' encoding='UTF-8'>
# True

# %%
with open("/Users/mac/Desktop/T1.text","w") as T3:
    T3.write("This is line one.\nThis is line two. \nFinally, we are on the third and last line of the file.")
with open("/Users/mac/Desktop/T1.text","r") as T3:
    
    number=1
    for i in T3:
        print("{}:{}".format(number,i.rstrip()))
        number += 1
        
    #用i可直接存取,一般都是打開之後來要用read()
# Out:
# 1:This is line one.
# 2:This is line two.
# 3:Finally, we are on the third and last line of the file.

# %%
#???
w=[]
with open("/Users/mac/Desktop/T4.text","w") as T4:
    T4.write("man\nbear\npig\ncow\nduck\nhorse\ndog\n")
with open("/Users/mac/Desktop/T4.text","r") as T4:    
    
    for i in T4:
        w.append(i)
        
    w.sort()
    print(w)
try:
    with open("/Users/mac/Desktop/sorted_file_name", 'w') as animals_sorted_file:
        for j in w:
            animals_sorted_file.write(j)
            print(j.rstrip())
            #只有在字串的時候才能用r.strip
except:
    print('Could not open {}.'.format(sorted_file_name))
# Out:
# ['bear\n', 'cow\n', 'dog\n', 'duck\n', 'horse\n', 'man\n', 'pig\n']
# bear
# cow
# dog
# duck
# horse
# man
# pig

# %%
from time import asctime, sleep

# %%
asctime()
# Out:
# 'Sun Aug 25 10:27:05 2019'

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'clock',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname',
#  'tzset']

# %%
import sys

for path  in sys.path:
    print(path)
# Out:
# /Users/mac/Documents/Scott_python
# /Users/mac/miniconda3/lib/python37.zip
# /Users/mac/miniconda3/lib/python3.7
# /Users/mac/miniconda3/lib/python3.7/lib-dynload
#
# /Users/mac/miniconda3/lib/python3.7/site-packages
# /Users/mac/miniconda3/lib/python3.7/site-packages/IPython/extensions
# /Users/mac/.ipython

# %%
sys.path
# Out:
# ['/Users/mac/Documents/Scott_python',
#  '/Users/mac/miniconda3/lib/python37.zip',
#  '/Users/mac/miniconda3/lib/python3.7',
#  '/Users/mac/miniconda3/lib/python3.7/lib-dynload',
#  '',
#  '/Users/mac/miniconda3/lib/python3.7/site-packages',
#  '/Users/mac/miniconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/mac/.ipython']
